# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Егор, привет!</b>
#
# Меня зовут Евгений Головин, я буду ревьюером твоего проекта. Если ты не против, то предлагаю построить наше общение на "ты" ;) Если удобнее на "вы", то нет проблем, только скажи об этом.
#
# В ходе работы я оставил тебе комментарии <font color='green'>зеленого</font>, <font color='gold'>желтого</font> и <font color='red'>красного</font> цветов. Сейчас объясню, что они значат:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Решение на этом шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Решение на этом шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  Решение на этом шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# Увидев мой комментарий, не удаляй его, он будет очень полезен в случае повторной проверки работы :)
#
# <div class="alert alert-info">
# <b>А свой помечай вот так, чтобы я его не потерял ;)</b>
# </div>
#
# На мои комменатрии можно и нужно реагировать, только делать это стоит так, чтобы твои и мои комменты не смешались: выделяй свои цветами, сильно отличающимися от моих.
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе аналитиком. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!

# %% [markdown]
# # Напишите заголовок проекта здесь
#
# - Автор: Василенко Егор
# - Дата: 27.12.2024-28.12.2024

# %% [markdown]
# ### Цели и задачи проекта

# %% [markdown]
# **Цель:** Провести исследовательский анализ рынка заведений общесвтенного питания Москвы
#
# **Задачи:**
# 1. Загрузить данные и познакомиться с их содержимым.
# 2. Провести предобработку данных.
# 3. Провести исследовательский анализ данных:
#     - Исследовать количество объектов общественного питания по каждой категории и ответить на вопрос "Какие категории заведений представлены в данных?";
#     - Исследовать распределение количества заведений по административным районам Москвы, а также отдельно распределение заведений каждой категории в Центральном административном округе Москвы и ответить на вопрос "Какие административные районы Москвы присутствуют в данных?";
#     - Изучить соотношение сетевых и несетевых заведений в целом по всем данным и в разрезе категорий заведения и ответить на вопросы: "Каких заведений больше — сетевых или несетевых?" и "Какие категории заведений чаще являются сетевыми?";
#     - Исследовать количество посадочных мест в заведениях, привести для каждой категории заведений наиболее типичное для него количество посадочных мест и ответить на вопросы: "Встречаются ли в данных аномальные значения или выбросы?" и "Если да, то с чем они могут быть связаны?";
#     - Исследовать рейтинг заведений и ответить на вопрос "Сильно ли различаются усреднённые рейтинги для разных типов общепита?";
#     - Изучить, с какими данными показывают самую сильную корреляцию рейтинги заведений;
#     - Сгруппировать данные по названиям заведений и найти топ-15 популярных сетей в Москве, для них посчитать значения среднего рейтинга. Ответить на вопрос: "К какой категории заведений они относятся?";
#     - Изучить вариацию среднего чека заведения (столбец `middle_avg_bill`) в зависимости от района Москвы. Проанализировать цены в центральном административном округе и других. Ответить на вопрос: "Как удалённость от центра влияет на цены в заведениях?"
# 4. Сформулировать выводы по проведённому анализу.

# %% [markdown]
# ### Описание данных
#
# Файл `/datasets/rest_info.csv` содержит информацию о заведениях общественного питания:
# - name — название заведения;
# - address — адрес заведения;
# - district — административный район, в котором находится заведение, например Центральный административный округ;
# - category — категория заведения, например «кафе», «пиццерия» или «кофейня»;
# - hours — информация о днях и часах работы;
# - rating — рейтинг заведения по оценкам пользователей в Яндекс Картах (высшая оценка — 5.0);
# - chain — число, выраженное 0 или 1, которое показывает, является ли заведение сетевым (для маленьких сетей могут встречаться ошибки):
#   - 0 — заведение не является сетевым;
#   - 1 — заведение является сетевым.
# - seats — количество посадочных мест.
#
# Файл `/datasets/rest_price.csv` содержит информацию о среднем чеке в заведениях общественного питания:
# - price — категория цен в заведении, например «средние», «ниже среднего», «выше среднего» и так далее;
# - avg_bill — строка, которая хранит среднюю стоимость заказа в виде диапазона, например:
#   - «Средний счёт: 1000–1500 ₽»;
#   - «Цена чашки капучино: 130–220 ₽»;
#   - «Цена бокала пива: 400–600 ₽».
#   - и так далее;
# - middle_avg_bill — число с оценкой среднего чека, которое указано только для значений из столбца avg_bill, начинающихся с подстроки «Средний счёт»:
#   - Если в строке указан ценовой диапазон из двух значений, в столбец войдёт медиана этих двух значений.
#   - Если в строке указано одно число — цена без диапазона, то в столбец войдёт это число.
#   - Если значения нет или оно не начинается с подстроки «Средний счёт», то в столбец ничего не войдёт.
# - middle_coffee_cup — число с оценкой одной чашки капучино, которое указано только для значений из столбца avg_bill, начинающихся с подстроки «Цена одной чашки капучино»:
#   - Если в строке указан ценовой диапазон из двух значений, в столбец войдёт медиана этих двух значений.
#   - Если в строке указано одно число — цена без диапазона, то в столбец войдёт это число.
#   - Если значения нет или оно не начинается с подстроки «Цена одной чашки капучино», то в столбец ничего не войдёт.

# %% [markdown]
# <a class="anchor" id="Содержание"></a>
# ### Содержимое проекта
#
# - [Загрузка данных, знакомство с ними и их обработка](#Знакомство-с-данными)
# - [Исследовательский анализ данных](#Исследовательский-анализ-данных)
#   - [Задача 1](#1)
#   - [Задача 2](#2)
#   - [Задача 3](#3)
#   - [Задача 4](#4)
#   - [Задача 5](#5)
#   - [Задача 6](#6)
#   - [Задача 7](#7)
#   - [Задача 8](#8)
#   - [Задача 9](#9)
#   - [Промежуточный вывод](#10)
# - [Итоговый вывод](#Итоговый-вывод)
# ---
#
# ---

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Отличное введение! Есть цель работы, план работы и описание данных. Молодец!

# %% [markdown]
# <a class="anchor" id="Знакомство-с-данными"></a>
# ## 1. Загрузка данных и знакомство с ними
#
# - Загрузите данные о заведениях общественного питания Москвы. Путь к файлам: `/datasets/rest_info.csv` и `/datasets/rest_price.csv`.

# %% [markdown]
# ***Импорт библиотек:***

# %%
# Для работы с данными
import pandas as pd
import numpy as np

# Для визуализации
import matplotlib.pyplot as plt
import seaborn as sns

# Для расчёта корреляции через phi_k
from phik import phik_matrix

# %% [markdown]
# ### Знакомство с данными и промежуточные выводы

# %%
# Загрузка датасетов/данных
rest_info = pd.read_csv('https://code.s3.yandex.net/datasets/rest_info.csv')
rest_price = pd.read_csv('https://code.s3.yandex.net/datasets/rest_price.csv')

# %% [markdown]
# - **Датасет `rest_info`:**

# %%
rest_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8406 entries, 0 to 8405
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        8406 non-null   object
#  1   name      8406 non-null   object
#  2   category  8406 non-null   object
#  3   address   8406 non-null   object
#  4   district  8406 non-null   object
#  5   hours     7870 non-null   object
#  6   rating    8406 non-null   float64
#  7   chain     8406 non-null   int64
#  8   seats     4795 non-null   float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 591.2+ KB

# %%
rest_info.head()
# Out:
#                                  id                  name  category  \
# 0  0c3e3439a8c64ea5bf6ecd6ca6ae19f0                WoWфли      кафе
# 1  045780ada3474c57a2112e505d74b633        Четыре комнаты  ресторан
# 2  1070b6b59144425896c65889347fcff6                 Хазри      кафе
# 3  03ac7cd772104f65b58b349dc59f03ee  Dormouse Coffee Shop   кофейня
# 4  a163aada139c4c7f87b0b1c0b466a50f             Иль Марко  пиццерия
#
#                                address                         district  \
# 0           Москва, улица Дыбенко, 7/1  Северный административный округ
# 1   Москва, улица Дыбенко, 36, корп. 1  Северный административный округ
# 2       Москва, Клязьминская улица, 15  Северный административный округ
# 3  Москва, улица Маршала Федоренко, 12  Северный административный округ
# 4      Москва, Правобережная улица, 1Б  Северный административный округ
#
#                                                hours  rating  chain  seats
# ...

# %% [markdown]
# **Вывод:**
#
# - Датасет содержит 9 столбцов и 8406 строк;
# - В 2-ух столбцах находятся пропуски: `hours` и `seats`;
# - Почти все столбцы имеют соответствующий тип данных. Исключением являtтся `seats`, а также можно изменить `chain` на булевый тип данных;
# - В целом, названия столбцов имеют хороший вид и приведения к другому не требуют;
# - Ориентрируясь на значения датасета, все они соответствуют описанию.

# %% [markdown]
# - **Датасет `rest_price`:**

# %%
rest_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4058 entries, 0 to 4057
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 4058 non-null   object
#  1   price              3315 non-null   object
#  2   avg_bill           3816 non-null   object
#  3   middle_avg_bill    3149 non-null   float64
#  4   middle_coffee_cup  535 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 158.6+ KB

# %%
rest_price.head()
# Out:
#                                  id          price  \
# 0  045780ada3474c57a2112e505d74b633  выше среднего
# 1  1070b6b59144425896c65889347fcff6        средние
# 2  03ac7cd772104f65b58b349dc59f03ee            NaN
# 3  a163aada139c4c7f87b0b1c0b466a50f        средние
# 4  8a343546b24e4a499ad96eb7d0797a8a        средние
#
#                         avg_bill  middle_avg_bill  middle_coffee_cup
# 0       Средний счёт:1500–1600 ₽           1550.0                NaN
# 1         Средний счёт:от 1000 ₽           1000.0                NaN
# 2  Цена чашки капучино:155–185 ₽              NaN              170.0
# 3         Средний счёт:400–600 ₽            500.0                NaN
# 4                            NaN              NaN                NaN

# %% [markdown]
# **Вывод:**
#
# - Датасет содержит 5 столбцов и 4058 строк;
# - Пропуски присутствуют в 4-ёх столбцах из 5-ти, а именно `price`, `avg_bill`, `middle_avg_bill` и `middle_coffee_cup`;
# - Значения во всех столбцах датаста соответствуют их описанию;
# - Все столбцы имеют хороший вид написания, а имено snake case.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Данные осмотрены верно!

# %% [markdown]
# ### Подготовка единого датафрейма

# %%
df = rest_info.merge(rest_price, on='id', how='left')

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>  А вот объединение проведено неверно, к сожалению. Обрати внимание на то, что здесь важно сохранить все данные из датафрейма с заведениями, даже несмотря на то, что не везде естть данные по чекам. Исправим эту ошибку и продолжим проверку. Код ниже придется зарефакторить

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>  А теперь все верно!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8406 entries, 0 to 8405
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 8406 non-null   object
#  1   name               8406 non-null   object
#  2   category           8406 non-null   object
#  3   address            8406 non-null   object
#  4   district           8406 non-null   object
#  5   hours              7870 non-null   object
#  6   rating             8406 non-null   float64
#  7   chain              8406 non-null   int64
#  8   seats              4795 non-null   float64
#  9   price              3315 non-null   object
#  10  avg_bill           3816 non-null   object
#  11  middle_avg_bill    3149 non-null   float64
#  12  middle_coffee_cup  535 non-null    float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 853.9+ KB

# %%
df.head()
# Out:
#                                  id                  name  category  \
# 0  0c3e3439a8c64ea5bf6ecd6ca6ae19f0                WoWфли      кафе
# 1  045780ada3474c57a2112e505d74b633        Четыре комнаты  ресторан
# 2  1070b6b59144425896c65889347fcff6                 Хазри      кафе
# 3  03ac7cd772104f65b58b349dc59f03ee  Dormouse Coffee Shop   кофейня
# 4  a163aada139c4c7f87b0b1c0b466a50f             Иль Марко  пиццерия
#
#                                address                         district  \
# 0           Москва, улица Дыбенко, 7/1  Северный административный округ
# 1   Москва, улица Дыбенко, 36, корп. 1  Северный административный округ
# 2       Москва, Клязьминская улица, 15  Северный административный округ
# 3  Москва, улица Маршала Федоренко, 12  Северный административный округ
# 4      Москва, Правобережная улица, 1Б  Северный административный округ
#
#                                                hours  rating  chain  seats  \
# ...

# %% [markdown]
# **Вывод:**
# - Объединение произведено по пересечениям `id`, чтобы оставалась полнота информации и не присутствовали заведения общественного питания без цен;
# - В итоговом датасете 8406 строк с пропусками в столбцах `seats`, `price`, `avg_bill`, `middle_avg_bill` и `middle_coffee_cup`.
# - Также остается несоответствие типов данных в столбцах `chain` в булевый, `seats` в целочисленный.
#
# ---
#
# [Вернуться к содержанию](#Содержание)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>  Данные импортированы и объединены верно!

# %% [markdown]
# ## 2. Предобработка данных

# %% [markdown]
# - **Работа с корректностью типов данных**

# %%
df.dtypes
# Out:
# id                    object
# name                  object
# category              object
# address               object
# district              object
# hours                 object
# rating               float64
# chain                  int64
# seats                float64
# price                 object
# avg_bill              object
# middle_avg_bill      float64
# middle_coffee_cup    float64
# dtype: object

# %%
df['seats'] = pd.to_numeric(df['seats'], errors='coerce')
df['chain'] = df['chain'].astype(bool)

# %%
df.dtypes
# Out:
# id                    object
# name                  object
# category              object
# address               object
# district              object
# hours                 object
# rating               float64
# chain                   bool
# seats                float64
# price                 object
# avg_bill              object
# middle_avg_bill      float64
# middle_coffee_cup    float64
# dtype: object

# %% [markdown]
# Типы данных преобразованы:
# - `seats` -> `float64`;
# - `chain` -> `bool`;
# - В последующем `seats` после заполнения пропусков будет проеобразован в `int`.

# %% [markdown]
# - **Работа с пропусками**

# %%
test_df_1 = df.copy()
test_df_1.shape[0]
# Out:
# 8406

# %%
print(f"Количество пропусков в абсолютных значениях:")
display(pd.DataFrame(df.isna().sum(), columns=['Total NaN'])
        .style.background_gradient('coolwarm'))
# Out:
# Количество пропусков в абсолютных значениях:
# <style type="text/css">
# #T_59105_row0_col0, #T_59105_row1_col0, #T_59105_row2_col0, #T_59105_row3_col0, #T_59105_row4_col0, #T_59105_row6_col0, #T_59105_row7_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_59105_row5_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_59105_row8_col0 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_59105_row9_col0 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_59105_row10_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_59105_row11_col0 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_59105_row12_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_59105">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_59105_level0_col0" class="col_heading level0 col0" >Total NaN</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
print(f"Количество пропусков в относительных значениях (%):")
display(pd.DataFrame(round((df.isna().mean()*100),2), columns=['NaNs, %'])
        .style.format( '{:.2f}').background_gradient('coolwarm'))
# Out:
# Количество пропусков в относительных значениях (%):
# <style type="text/css">
# #T_0ac0b_row0_col0, #T_0ac0b_row1_col0, #T_0ac0b_row2_col0, #T_0ac0b_row3_col0, #T_0ac0b_row4_col0, #T_0ac0b_row6_col0, #T_0ac0b_row7_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_0ac0b_row5_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_0ac0b_row8_col0 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_0ac0b_row9_col0 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_0ac0b_row10_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_0ac0b_row11_col0 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_0ac0b_row12_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0ac0b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0ac0b_level0_col0" class="col_heading level0 col0" >NaNs, %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# Мини-вывод по пропускам:
#
# - `hours`: можно заменить пропуски на "не указано" или же просто удалить (так как эти строки составляют всего 0.2% всех строк), но я решил выбрать первый вариант, создав ещё одну категорию в этом столбце;
# - `seats`: здесь можно взять медианные значения в разрезе категорий;
# - `price`: можно заполнить на основе столбцов со средними чеками и с оценкой одной чашки капучино;
# - `avg_bill`: заполнить логически не представляется возможным, поэтому их стоит либо удалить или же создать отдельную категорию;
# - `middle_avg_bill`: обозначить индикатором -1 отсутствие данных или оставить просто пропуск;
# - `middle_coffee_cup`: обозначить индикатором -1 отсутствие данных или оставить просто пропуск.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>  Отличная проверка пропусков! Здорово, что проверяешь и доли, и количество. Хвалю!

# %% [markdown]
# ---
# - *Замены в столбцах `middle_avg_bill` и `middle_coffee_cup`.*

# %%
# Функция для замены
def extract_median(value, prefix):
    # Если строка пустая или не начинается с нужного префикса возвращается пропуск
    if pd.isna(value) or not value.startswith(prefix):
        return np.nan
    
    # Убираются префикс, двоеточие и ₽, оставляя только интервалы
    numeric_part = value.replace(prefix, "").replace(":", "").strip()
    numeric_part = numeric_part.split("₽")[0].strip()
    
    # Если указан диапазон, берём медиану
    if "–" in numeric_part:
        low, high = map(int, numeric_part.split("–"))
        return (low + high) / 2
    # Если указано одно число, то возвращается оно
    elif "от" in numeric_part:
        return int(numeric_part.replace("от", "").strip())
    elif "до" in numeric_part:
        return int(numeric_part.replace("до", "").strip())
    else:
        return int(numeric_part)

# %%
df['middle_avg_bill'] = df['middle_avg_bill'].combine_first(df['avg_bill'].apply(lambda x: extract_median(x, "Средний счёт:")))
df['middle_coffee_cup'] = df['middle_coffee_cup'].combine_first(df['avg_bill'].apply(lambda x: extract_median(x, "Цена чашки капучино:")))

# %%
print(f"Количество пропусков в относительных значениях (%):")
display(pd.DataFrame(round((df.isna().mean()*100),2), columns=['NaNs, %'])
        .style.format( '{:.2f}').background_gradient('coolwarm'))
# Out:
# Количество пропусков в относительных значениях (%):
# <style type="text/css">
# #T_d8d35_row0_col0, #T_d8d35_row1_col0, #T_d8d35_row2_col0, #T_d8d35_row3_col0, #T_d8d35_row4_col0, #T_d8d35_row6_col0, #T_d8d35_row7_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d8d35_row5_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_d8d35_row8_col0 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_d8d35_row9_col0 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_d8d35_row10_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_d8d35_row11_col0 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_d8d35_row12_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d8d35">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8d35_level0_col0" class="col_heading level0 col0" >NaNs, %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# После выполнения функции доля пропусков не изменилась, что лишь говорит об отсутствии некорректных заполнений в соответствии с указанной логикой в описании данных. Соответственно, эти пропуски можно заменить на индикатор -1, как показатель отсутствия данных или как такого такого показателя для заведения, или оставить так, как есть. Однако, это стоит учитывать это в будущем.

# %%
df['middle_avg_bill'] = df['middle_avg_bill'].fillna(-1)
df['middle_coffee_cup'] = df['middle_coffee_cup'].fillna(-1)

# %% [markdown]
# <div style="background-color:#abebc6 ; padding:10px; border-radius:5px;">
#     Учтём то, что теперь в этих столбцах -1 является индикатором отсутствия этих данных.
# </div>

# %%
print(f"Количество пропусков в относительных значениях (%):")
display(pd.DataFrame(round((df.isna().mean()*100),2), columns=['NaNs, %'])
        .style.format( '{:.2f}').background_gradient('coolwarm'))
# Out:
# Количество пропусков в относительных значениях (%):
# <style type="text/css">
# #T_3f44d_row0_col0, #T_3f44d_row1_col0, #T_3f44d_row2_col0, #T_3f44d_row3_col0, #T_3f44d_row4_col0, #T_3f44d_row6_col0, #T_3f44d_row7_col0, #T_3f44d_row11_col0, #T_3f44d_row12_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_3f44d_row5_col0 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_3f44d_row8_col0 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_3f44d_row9_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3f44d_row10_col0 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3f44d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f44d_level0_col0" class="col_heading level0 col0" >NaNs, %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f44d_level0_row0" class="row_heading level0 row0" >id</th>
# ...

# %% [markdown]
# ---
# - *Работа с пропусками в столбцах `hours` и `avg_bill`.*

# %%
df['hours'] = df['hours'].fillna("не указано")
df['avg_bill'] = df['avg_bill'].fillna("Не указано")

# %% [markdown]
# Для этих столбцов из-за недостаточности данных для логической замены введены новые категории "не указано" и "Не указано".

# %% [markdown]
# ---
# - *Работа с пропусками в столбце `seats`.*

# %%
df['category'].unique()
# Out:
# array(['кафе', 'ресторан', 'кофейня', 'пиццерия', 'бар,паб',
#        'быстрое питание', 'булочная', 'столовая'], dtype=object)

# %%
median_seats_by_category = df.groupby('category').agg({'seats':'median'}).reset_index()
median_seats_by_category
# Out:
#           category  seats
# 0          бар,паб   82.5
# 1         булочная   50.0
# 2  быстрое питание   65.0
# 3             кафе   60.0
# 4          кофейня   80.0
# 5         пиццерия   55.0
# 6         ресторан   86.0
# 7         столовая   75.5

# %%
# Объединяем оригинальный DataFrame с медианами
df = df.merge(median_seats_by_category, on='category', how='left', suffixes=('', '_median'))

# Заполняем пропуски значениями из нового столбца
df['seats'] = df['seats'].fillna(df['seats_median'])

# Убираем вспомогательный столбец
df = df.drop(columns=['seats_median'])

# %%
# Дополнительно преобразуем в целочисленный тип
df['seats'] = df['seats'].astype(int)

# %%
print(f"Количество пропусков в относительных значениях (%):")
display(pd.DataFrame(round((df.isna().mean()*100),2), columns=['NaNs, %'])
        .style.format( '{:.2f}').background_gradient('coolwarm'))
# Out:
# Количество пропусков в относительных значениях (%):
# <style type="text/css">
# #T_5634d_row0_col0, #T_5634d_row1_col0, #T_5634d_row2_col0, #T_5634d_row3_col0, #T_5634d_row4_col0, #T_5634d_row5_col0, #T_5634d_row6_col0, #T_5634d_row7_col0, #T_5634d_row8_col0, #T_5634d_row10_col0, #T_5634d_row11_col0, #T_5634d_row12_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5634d_row9_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5634d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5634d_level0_col0" class="col_heading level0 col0" >NaNs, %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5634d_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_5634d_row0_col0" class="data row0 col0" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_5634d_level0_row1" class="row_heading level0 row1" >name</th>
# ...

# %% [markdown]
# Пропуски в столбце `seats` заполнены медианным значением в разрезе категорий.

# %% [markdown]
# ---
# - *Работа с пропусками в столбце `price`.*

# %%
# Анализ диапазонов для middle_avg_bill
df.groupby('price')['middle_avg_bill'].describe()
# Out:
#                 count         mean          std  min     25%     50%      75%  \
# price
# высокие         478.0  2260.458159  1917.707325 -1.0  1750.0  2000.0  2500.00
# выше среднего   564.0  1146.226950   520.918507 -1.0  1200.0  1250.0  1500.00
# низкие          156.0   129.147436   139.107144 -1.0    -1.0   135.0   191.25
# средние        2117.0   471.672178   358.683717 -1.0   250.0   400.0   750.00
#
#                    max
# price
# высокие        35000.0
# выше среднего   4500.0
# низкие           600.0
# средние         2150.0

# %%
# Анализ диапазонов для middle_coffee_cup
df.groupby('price')['middle_coffee_cup'].describe()
# Out:
#                 count       mean        std  min  25%  50%    75%     max
# price
# высокие         478.0  -0.474895  11.480473 -1.0 -1.0 -1.0   -1.0   250.0
# выше среднего   564.0  -0.276596  12.541572 -1.0 -1.0 -1.0   -1.0   256.0
# низкие          156.0  49.282051  70.553278 -1.0 -1.0 -1.0  121.0   256.0
# средние        2117.0  20.666509  72.666186 -1.0 -1.0 -1.0   -1.0  1568.0

# %%
# Функция для категоризации по уровню цены
def fill_price_simplified(row):
    # Проверка и обработка middle_avg_bill
    if pd.notna(row['middle_avg_bill']) and row['middle_avg_bill'] > 0:
        if row['middle_avg_bill'] <= 500:
            return "низкие"
        elif row['middle_avg_bill'] <= 1500:
            return "средние"
        elif row['middle_avg_bill'] <= 2500:
            return "выше среднего"
        else:
            return "высокие"
    
    # Проверка и обработка middle_coffee_cup
    if pd.notna(row['middle_coffee_cup']) and row['middle_coffee_cup'] > 0:
        if row['middle_coffee_cup'] <= 150:
            return "низкие"
        elif row['middle_coffee_cup'] <= 200:
            return "средние"
        elif row['middle_coffee_cup'] <= 250:
            return "выше среднего"
        else:
            return "высокие"
    
    # Если данные отсутствуют или некорректны
    return "не указано"

# %%
df['price'] = df.apply(fill_price_simplified, axis=1)

# %%
df['price'].value_counts()
# Out:
# price
# не указано       4723
# средние          1538
# низкие           1488
# выше среднего     461
# высокие           196
# Name: count, dtype: int64

# %%
print(f"Количество пропусков в относительных значениях (%):")
display(pd.DataFrame(round((df.isna().mean()*100),2), columns=['NaNs, %'])
        .style.format( '{:.2f}').background_gradient('coolwarm'))
# Out:
# Количество пропусков в относительных значениях (%):
# <style type="text/css">
# #T_c3ed2_row0_col0, #T_c3ed2_row1_col0, #T_c3ed2_row2_col0, #T_c3ed2_row3_col0, #T_c3ed2_row4_col0, #T_c3ed2_row5_col0, #T_c3ed2_row6_col0, #T_c3ed2_row7_col0, #T_c3ed2_row8_col0, #T_c3ed2_row9_col0, #T_c3ed2_row10_col0, #T_c3ed2_row11_col0, #T_c3ed2_row12_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c3ed2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3ed2_level0_col0" class="col_heading level0 col0" >NaNs, %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3ed2_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_c3ed2_row0_col0" class="data row0 col0" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c3ed2_level0_row1" class="row_heading level0 row1" >name</th>
#       <td id="T_c3ed2_row1_col0" class="data row1 col0" >0.00</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# Логику в разделении на ценовые категории в столбце `price` обнаружить достаточно сложно, хотя некоторая и присутствует. Однако в нём есть достаточно существенные выбросы, которые не позволяют понять то, чем руководствовались при разделении. Конечно, это также может быть и ошибка при сборе данных или их заполнении, но мной были приблизительно установлены границы на основе приблизительного представления логики для каждой категории, по которым я произвел дополнительное разделение.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>  Все пропуски отработтаны верно! Детальная качественная работа

# %% [markdown]
# - Проверьте данные на явные и неявные дубликаты, например поля с названием и адресом заведения. Для оптимизации проверки нормализуйте данные в текстовых столбцах, например с названием заведения.

# %%
df.duplicated(subset='id').sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
columns = ['name', 'address', 'hours']

for column in columns:
    df[column] = df[column].str.lower().str.strip()

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Уметсно использование цикла для автоматизации

# %% [markdown]
# <div class="alert alert-info">
# <b>Изменил на цикл</b>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v3 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Отлично!

# %%
for column in ['name', 'address', 'district']:
    print(f'Уникальные значения в столбце {column}:')
    print(df[column].sort_values().unique())
    print()
# Out:
# Уникальные значения в столбце name:
# ['#кешбэккафе' '+39 pizzeria mozzarella bar' '1 этаж' ... 'ё-ланч'
#  'ёж и устрица' 'ёрш']
#
# Уникальные значения в столбце address:
# ['москва, 1-й автозаводский проезд, 5'
#  'москва, 1-й балтийский переулок, 3/25'
#  'москва, 1-й варшавский проезд, 1ас9' ...
#  'москва, яузский бульвар, 11, стр. 1' 'москва, яузский бульвар, 14/8'
#  'москва, № 7']
#
# Уникальные значения в столбце district:
# ['Восточный административный округ' 'Западный административный округ'
#  'Северный административный округ'
#  'Северо-Восточный административный округ'
#  'Северо-Западный административный округ'
#  'Центральный административный округ'
#  'Юго-Восточный административный округ'
#  'Юго-Западный административный округ' 'Южный административный округ']

# %% [markdown]
# - Явных дубликатов нет;
# - Предполжительные явные дубликаты убраны преобразование данных к единому виду.

# %% [markdown]
# ---
# - Для дальнейшей работы создайте столбец `is_24_7` с обозначением того, что заведение работает ежедневно и круглосуточно, то есть 24/7:
#   - логическое значение `True` — если заведение работает ежедневно и круглосуточно;
#   - логическое значение `False` — в противоположном случае.

# %%
# Функция для создания столбца с булевыми значениями
def check_24_7(hours):
    if 'круглосуточно' in hours and 'ежедневно' in hours:
        return True
    else:
        return False

# %%
df['is_24_7'] = df['hours'].apply(check_24_7)

# %%
df['is_24_7'].value_counts()
# Out:
# is_24_7
# False    7676
# True      730
# Name: count, dtype: int64

# %% [markdown]
# Создан столбец `is_24_7` с булевым типом данных в соответствии с условием задания.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>  Столбец добавлен правильно!

# %% [markdown]
# ---
#
# ### Промежуточный вывод

# %% [markdown]
# - Удалённых данных нет;
# - Преобразованы данные к соответствующему типу:
#   - `seats` -> `float64`;
#   - `chain` -> `bool`;
#   - В последующем `seats` после заполнения пропусков будет проеобразован в `int`.
# - Явные дубликаты отсутствуют, в том числе сугубо по столбцу `id`, а данные с предполагаемыми неявными дубликатами преобразованы к единому виду;
# - Пропуски были заполнены:
#   - В столбце `seats` медианным значением в разрезе категорий;
#   - В столбцах `middle_avg_bill` и `middle_coffee_cup` индикатором -1;
#   - В столбце `price` предполагаемой категоризацией;
#   - В столбцах `hours` и `avg_bill` созданы категории "не указано" и "Не указано".
#
# ---
#
# [Вернуться к содержанию](#Содержание)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>  Здорово, что добавляешь промежуточный вывод. Молодец!

# %% [markdown]
# <a class="anchor" id="Исследовательский-анализ-данных"></a>
# ## 3. Исследовательский анализ данных

# %% [markdown]
# ---
# <a class="anchor" id="1"></a>
# ### Задача 1
#
# Какие категории заведений представлены в данных? Исследуйте количество объектов общественного питания по каждой категории. Результат сопроводите подходящей визуализацией.

# %%
rest_count_by_category = df.groupby('category').agg({'id':'count'}).reset_index()

# %%
rest_count_by_category_sorted = rest_count_by_category.sort_values(by='id', ascending=False)

# %%
plt.figure(figsize=(10,6))

ax = sns.barplot(rest_count_by_category_sorted, x='id', y='category', color='#c0392b')

ax.bar_label(ax.containers[0], fontsize=10, color='black', fmt='%d', padding=1)

plt.title("Количество заведений по категориям")
plt.ylabel("Категория")
plt.xlabel("Количество")
plt.tight_layout()
plt.show()

# %% [markdown]
# Вывод:
# - В данных представлено 8 категорий:`ресторан`, `кофейня`, `кафе`, `бар,паб`, `пиццерия`, `быстрое питание`, `столовая` и `булочная`.
# - Наиболее популярными категориями заведений в данных являются рестораны, кофейни и кафе, однако рестораны b кафе имеют достаточно существенное преимущество над остальными.
#
# ---
# [Вернуться к содержанию](#Содержание)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Сделано правильно, молодец!

# %% [markdown]
# ---
# <a class="anchor" id="2"></a>
# ### Задача 2
#
# Какие административные районы Москвы присутствуют в данных? Исследуйте распределение количества заведений по административным районам Москвы, а также отдельно распределение заведений каждой категории в Центральном административном округе Москвы. Результат сопроводите подходящими визуализациями.

# %%
df.columns
# Out:
# Index(['id', 'name', 'category', 'address', 'district', 'hours', 'rating',
#        'chain', 'seats', 'price', 'avg_bill', 'middle_avg_bill',
#        'middle_coffee_cup', 'is_24_7'],
#       dtype='object')

# %%
rest_by_district = df.pivot_table(index='district', values='id', aggfunc='count').reset_index()

# %%
rest_by_district_sorted = rest_by_district.sort_values(by='id', ascending=False)
rest_by_district_sorted
# Out:
#                                   district    id
# 5       Центральный административный округ  2242
# 2          Северный административный округ   900
# 8             Южный административный округ   892
# 3  Северо-Восточный административный округ   891
# 1          Западный административный округ   851
# 0         Восточный административный округ   798
# 6     Юго-Восточный административный округ   714
# 7      Юго-Западный административный округ   709
# 4   Северо-Западный административный округ   409

# %%
plt.figure(figsize=(10,6))

ax = sns.barplot(rest_by_district_sorted, x='id', y='district', hue='district', palette='inferno')

plt.xlim(0, rest_by_district_sorted['id'].max() * 1.1)

for i in range(len(list(df['district'].unique()))):
    ax.bar_label(ax.containers[i], fontsize=10, color='black', fmt='%d', padding=1)

plt.title("Количество заведений по административный районам Москвы")
plt.ylabel("Регион")
plt.xlabel("Количество")
plt.tight_layout()
plt.show()

# %% [markdown]
# Вывод:
# - Наибольшее количество заведений оказалось в Центральном административном округе;
# - Остальные обладают существенно более низким количеством заведений, где с самым низким количеством выделяется Северо-Западным административный округ.

# %%
cent_rest_by_category = df[df['district'] == "Центральный административный округ"].groupby('category').agg({'id':'count'}).reset_index()
cent_rest_by_category_sorted = cent_rest_by_category.sort_values(by='id', ascending=False)
cent_rest_by_category_sorted
# Out:
#           category   id
# 6         ресторан  670
# 3             кафе  464
# 4          кофейня  428
# 0          бар,паб  364
# 5         пиццерия  113
# 2  быстрое питание   87
# 7         столовая   66
# 1         булочная   50

# %%
plt.figure(figsize=(10,6))

ax = sns.barplot(cent_rest_by_category_sorted, x='id', y='category', color='#c0392b')

ax.bar_label(ax.containers[0], fontsize=10, color='black', fmt='%d', padding=1)

plt.title("Количество заведений по категориям в Центральном административном округе")
plt.ylabel("Категория")
plt.xlabel("Количество")
plt.tight_layout()
plt.show()

# %% [markdown]
# Вывод:
# - Категория ресторанов среди заведений Москвы доминирует в Центральном административном округе;
# - Наименее популярной категорией в данных являются булочные;
# - В топ-3 также входят кафе и кофейни.
#
# ---
# [Вернуться к содержанию](#Содержание)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>  Правильно, молодец!

# %% [markdown]
# ---
# <a class="anchor" id="3"></a>
# ### Задача 3
#
# Изучите соотношение сетевых и несетевых заведений в целом по всем данным и в разрезе категорий заведения. Каких заведений больше — сетевых или несетевых? Какие категории заведений чаще являются сетевыми? Исследуйте данные, ответьте на вопросы и постройте необходимые визуализации.

# %%
df.columns
# Out:
# Index(['id', 'name', 'category', 'address', 'district', 'hours', 'rating',
#        'chain', 'seats', 'price', 'avg_bill', 'middle_avg_bill',
#        'middle_coffee_cup', 'is_24_7'],
#       dtype='object')

# %%
chain_grouped = df.groupby('chain').agg({'id':'count'}).reset_index()

# %%
plt.figure(figsize=(10,6))

ax = sns.barplot(chain_grouped, 
                 x='id', y='chain', hue='chain', palette=['#c0392b','#48c9b0'],
                 legend=True, orient='h')

plt.xlim(0, chain_grouped['id'].max() * 1.1)
ax.legend(title='Сетевое')

for i in range(2):
    ax.bar_label(ax.containers[i], fontsize=10, color='black', fmt='%2d', padding=3)

plt.title("Распределение сетевых и несетевых заведений")
plt.ylabel("")
plt.xlabel("Количество")
plt.tight_layout()
plt.show()

# %%
rest_by_chain_and_category = df.groupby(['category']).agg({'chain':'mean'}) * 100
rest_by_chain_and_category.sort_values(by='chain', ascending=False, inplace=True)
rest_by_chain_and_category
# Out:
#                      chain
# category
# булочная         61.328125
# пиццерия         52.132701
# кофейня          50.955414
# быстрое питание  38.474295
# ресторан         35.731767
# кафе             32.758621
# столовая         27.936508
# бар,паб          22.091503

# %%
plt.figure(figsize=(10,6))

ax = sns.barplot(rest_by_chain_and_category.reset_index(), x='category', y='chain', color='#48c9b0')

ax.bar_label(ax.containers[0], fontsize=10, color='black', fmt='%0.1f%%', padding=1)

plt.title("Доля сетевых заведений в разрезе категорий (%)")
plt.ylabel("Доля в %")
plt.xlabel("Категория")
plt.tight_layout()
plt.show()

# %% [markdown]
# Вывод:
# - В целом, несетевых заведений больше, причем существенно - практически на 2000 заведений, и это при том, что всего заведений 4058;
# - Наибольшая доля сетевых заведений в таких категориях, как булочные, кофейни и пиццерии;
# - Наименьшая доля сетевых заведений в категориях: бар, паб, столовая и кафе;
# - В заключение, итог достаточно логичный и соответствующий реальности.
#
# ---
# [Вернуться к содержанию](#Содержание)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v2<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>  Общее соотношение сетевых и несетевых заведений исследовано верно, но вот визуализация по категориям неверна. Визуализировть нужно именно доли сетевых заведений

# %% [markdown]
# <div class="alert alert-info">
# <b>Переделал, изменив на доли сетевых в %. Выводы также исправил: и по пункту, и итоговый</b>
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v3 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Добаавь еще сорировку, пожалуйста

# %% [markdown]
# ---
# <a class="anchor" id="4"></a>
# ### Задача 4
#
# Исследуйте количество посадочных мест в заведениях. Встречаются ли в данных аномальные значения или выбросы? Если да, то с чем они могут быть связаны? Приведите для каждой категории заведений наиболее типичное для него количество посадочных мест. Результат сопроводите подходящими визуализациями.

# %%
plt.figure(figsize=(10,6))

sns.histplot(df['seats'], kde=True, bins=70, color='#8e44ad')

plt.title("Распределение по столбцу посадочных мест (seats)")
plt.ylabel("Частота")
plt.xlabel("Количество посадочных мест")
plt.tight_layout()
plt.show()

# %% [markdown]
# Уже по графику распределения видно, что даннве столбца `seats` не являются ни нормальными, ни симметричными. Скорее их можно охарактеризовать ассиметричными вправо, причем достаточно сильно.

# %%
plt.figure(figsize=(10,6))

sns.boxplot(data=df, x='seats', color='#8e44ad',
            flierprops=dict(markerfacecolor='r', marker='o', markersize=5, markeredgewidth=0.5))

plt.title("Boxplot по столбцу посадочных мест (seats)")
plt.xlabel("Количество посадочных мест")
plt.tight_layout()
plt.show()

# %% [markdown]
# В данных встречается аномальное количество посадочных мест, что может быть связано с наличием действительно больших помещений для организации различных больших мероприятий или же с некорректным заполнением данных (например, вместо 120 было написано 1200, что является следствием опечатки), но я всё же склоняюсь к высокой вероятности варианты заведений, специализирующихся, или просто имеющих такие зоны, на мероприятиях.
#
# Также в данных присутствуют нулевые значения по столбцу `seats`, что может свит+детельствовать либо о выбросах, либо о то, что в заведении просто-напросто нет посадочных мест.

# %%
df[df['seats'] == 0]
# Out:
#                                     id                        name  \
# 84    3793bd736bbb4dd08f734d53bfa57b24            meat doner kebab
# 177   3fb68f4204274347b94b5cb397fedce7                      арамье
# 196   bfd0d5a3a91f43e9a43f4a5fe96144f1                донер-шашлык
# 203   78f050b65d4146ef932b734db72e1e86                  тандыр № 1
# 211   4636272b73bd40c59c156725492f2c05            неаполитан пицца
# ...                                ...                         ...
# 8118  deb866a144a04546a16f9ec508a25aa7                        бико
# 8168  54ad4021be444c358be987072f51e7d0            чайхана уч кудук
# 8172  b1f7555a82a34a0fb7c42f0818addd99                  масса кофе
# 8336  595fefac108748ae9d158d93cf376c70  сочная шаурма в кузьминках
# 8362  6b613565645e4c05a70ddd7d2badd502                      достор
#
#              category                                      address  \
# 84           булочная                    москва, улица лескова, 22
# ...

# %% [markdown]
# В целом, из этих строк видно, что частично это явно ошибка в заполнении данных, а частично в некоторых заведениях в действительности может не быть посадочных мест в связи с их моделью работы.

# %%
plt.figure(figsize=(10,6))

sns.boxplot(data=df, x='seats', showfliers=False, color='#8e44ad')

plt.title("Boxplot по столбцу посадочных мест (seats)")
plt.xlabel("Количество посадочных мест")
plt.tight_layout()
plt.show()

# %% [markdown]
# На данном графике положение медианы ещё раз говорит нам о несимметричности данных по столбцу.

# %%
df.columns
# Out:
# Index(['id', 'name', 'category', 'address', 'district', 'hours', 'rating',
#        'chain', 'seats', 'price', 'avg_bill', 'middle_avg_bill',
#        'middle_coffee_cup', 'is_24_7'],
#       dtype='object')

# %% [markdown]
# Наиболее типичным количеством буду считать моду, что, как по мне, логично в связи с наиболее частым количеством такого числа мест.

# %%
# Группировка по категориям и нахождение моды (наиболее частого значения)
typical_seats_by_category = df.groupby('category')['seats'].agg(lambda x: x.mode()[0] if not x.mode().empty else None)

# Преобразуем в DataFrame для удобства
typical_seats_by_category = typical_seats_by_category.reset_index()
typical_seats_by_category.columns = ['category', 'typical_seats']

typical_seats_by_category.sort_values(by='typical_seats', ascending=False, inplace=True)
typical_seats_by_category
# Out:
#           category  typical_seats
# 6         ресторан             86
# 0          бар,паб             82
# 4          кофейня             80
# 7         столовая             75
# 2  быстрое питание             65
# 3             кафе             60
# 5         пиццерия             55
# 1         булочная             50

# %%
plt.figure(figsize=(10,6))

ax = sns.barplot(typical_seats_by_category, x='category', y='typical_seats', color='#8e44ad')

ax.bar_label(ax.containers[0], fontsize=10, color='black', fmt='%d', padding=1)

plt.ylim(30, 100)

plt.title("Типичное количество посадочных мест для каждой из категорий")
plt.ylabel("Количество")
plt.xlabel("Категория")
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Не забывай сортировать столбчатую диаграмму

# %% [markdown]
# <div class="alert alert-info">
# <b>Отсортировал</b>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v3 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Молодец!

# %% [markdown]
# На данной столбцатой диаграмме представлены наиболее типичное количество посадочных мест для каждой категории. Для примера наибольшее количество мест среди типичным у ресторанов, что ожидаемо. Сразу же за ними идут бары, пабы с 82 посадочными местами, что, наверное, тоже объяснимо.
#
# - Среди категорийй с самым меньших типичным количеством посадочных мест выделяютсмя пиццерии и булочные.
# - Аномальным выглядит типичное количество посадочных мест для кофеен в размере 80 мест.
#
# ---
# [Вернуться к содержанию](#Содержание)

# %% [markdown]
# ---
# <a class="anchor" id="5"></a>
# ### Задача 5
#
# Исследуйте рейтинг заведений. Визуализируйте распределение средних рейтингов по категориям заведений. Сильно ли различаются усреднённые рейтинги для разных типов общепита?

# %%
avg_rating_by_category = df.groupby('category').agg({'rating': 'mean'}).sort_values(by='rating', ascending=False)
avg_rating_by_category
# Out:
#                    rating
# category
# бар,паб          4.387712
# пиццерия         4.301264
# ресторан         4.290357
# кофейня          4.277282
# булочная         4.268359
# столовая         4.211429
# кафе             4.123886
# быстрое питание  4.050249

# %%
plt.figure(figsize=(10,6))

ax = sns.barplot(avg_rating_by_category.reset_index(), x='category', y='rating', color='#ffd942', alpha=0.6)

ax.bar_label(ax.containers[0], fontsize=10, color='black', fmt='%.2f', padding=1)

plt.ylim(3, 5)

plt.title("Распределение средних рейтингов по категориям заведений")
plt.ylabel("Средний рейтинг")
plt.xlabel("Категория")
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Вновь не хватает сортировки. В остальном - отлично!

# %% [markdown]
# <div class="alert alert-info">
# <b>Отсортировал</b>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v3 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Молодец!

# %% [markdown]
# По данному рейтингу видно, что отличия рейтинг несущественны. В среднем рейтинг у каждой категории держится на уровне 4.10-4.20 с небольшими погрешностями в меньшую или большую стороны, что несущественно.
#
# - С наивысшим средним ретингом выделяются бары, пабы;
# - С наименьшим средним рейтингом выделяются заведения быстрого питания.
#
# Сложно предположить с чем связан такой разрыв, однако он все равно достаточно несущественный.
#
# ---
# [Вернуться к содержанию](#Содержание)

# %% [markdown]
# ---
# <a class="anchor" id="6"></a>
# ### Задача 6
#
# Изучите, с какими данными показывают самую сильную корреляцию рейтинги заведений? Постройте и визуализируйте матрицу корреляции рейтинга заведения с разными данными: его категория, положение (административный район Москвы), статус сетевого заведения, количество мест, ценовая категория и признак, является ли заведения круглосуточным. Выберите самую сильную связь и проверьте её.

# %% [markdown]
# **Корреляционная матрица общая и отдельная для `rating`**

# %%
df.columns
# Out:
# Index(['id', 'name', 'category', 'address', 'district', 'hours', 'rating',
#        'chain', 'seats', 'price', 'avg_bill', 'middle_avg_bill',
#        'middle_coffee_cup', 'is_24_7'],
#       dtype='object')

# %%
# Выберем столбцы, которые нам необходимы по условиям задания
columns = ['rating', 'category', 'district', 'chain', 'seats', 'price', 'is_24_7']

# %%
matrix_for_rating = df[columns].phik_matrix()
# Out:
# interval columns not set, guessing: ['rating', 'seats']

# %%
plt.figure(figsize=(8,6))

sns.heatmap(matrix_for_rating, annot=True, cmap='coolwarm')

plt.title("Корреляционная матрица phi_k")
plt.ylabel("")
plt.xlabel("")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,6))

sns.heatmap(matrix_for_rating.loc[:,['rating']], annot=True, cmap='coolwarm')

plt.title("Корреляционная матрица phi_k только для rating")
plt.ylabel("")
plt.xlabel("")
plt.tight_layout()
plt.show()

# %% [markdown]
# Наибольшая связь со столбцом `rating` у `price`, однако даже она достаточно мала.

# %% [markdown]
# **Проверка связи `rating` и `price`**

# %%
# Повторим датафрейм со средними рейтингами
avg_rating_by_category
# Out:
#                    rating
# category
# бар,паб          4.387712
# пиццерия         4.301264
# ресторан         4.290357
# кофейня          4.277282
# булочная         4.268359
# столовая         4.211429
# кафе             4.123886
# быстрое питание  4.050249

# %%
category_and_rating = df[['price', 'rating']]

# %%
plt.figure(figsize=(10, 6))

sns.catplot(data=df, x='price', y='rating',
    kind='strip',
    jitter=True,  # Добавляем "разброс" точек для удобного чтения
    palette='viridis', hue='price',
    height=6, aspect=2)

plt.title("Распределение рейтингов по ценовой категории (stripplot)")
plt.xlabel("Категория цены")
plt.ylabel("Рейтинг")
plt.grid(axis='y')

plt.show()

# %% [markdown]
# На данном графике видно, что большинство рейтингов в ценовых категориях сконцентрированы в диапазоне 4–5.
#
# - Для категории "высокие" наблюдается большая плотность точек с рейтингами выше 4, но отсутствуют значения с рейтингамом 5;
# - Категории "средние" и "низкие" также показывают ещё большую концентрацию точек в области 4, но с некоторыми значениями ниже 3, что указывает на наличие заведений с низкой оценкой. Однако, как можно увидеть, наибольшее количество точек у средней ценовой категории находится выше, то есть больше заведений этой категории имеет имеют рейтинг, близкий к 5;
# - У низкой ценовой категории наблюдается такая же плотность на высоких значениях, но также присутствует более высокий разброс к низкому значению;
# - Категория "не указано" многообразна и имеет много значений. Здесь наблюдается высокая плотность в значениях рейтинга выше 3.0, но разброс значений ниже.
#
# В целом, сложно сказать о том, что существует действительно какая-либо явная связь - это подтверждает, хоть и самое высокое, но все равно низкое значение коэффициента корреляции, равное 0.28.

# %%
plt.figure(figsize=(10, 6))

sns.catplot(data=df, x='price', y='rating',
    kind='violin',
    palette='viridis', hue='price',
    height=6, aspect=2)

plt.title("Распределение рейтингов по ценовой категории (violinplot)")
plt.xlabel("Категория цены")
plt.ylabel("Рейтинг")
plt.grid(axis='y')

plt.show()

# %% [markdown]
# Этот график подтверждает выводы, сделанные ранее. Если исключать категорию "не указано", то более дорогие заведения имеют более высокие оценки, однако это разница несущественна.

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(data=df, x='price', y='rating', hue='price',
            palette='viridis', showmeans=True,
            meanprops={"marker": "x", "markeredgecolor": "black"},
            flierprops=dict(markerfacecolor='r', marker='o', markersize=3, markeredgewidth=0.5)
           )

plt.title("Распределение рейтингов по ценовой категории (Boxplot)")
plt.xlabel("Категория")
plt.ylabel("Рейтинг")
plt.grid(axis='y')

plt.tight_layout()
plt.show()

# %% [markdown]
# На этом графике намного лучше видно, что у более высокой ценовой категории и рейтинг выше. Об этом можно судить по средним, но тут же мы видим и то, что категория "выше среднего" в среднем выше оценена, чем "высокие". Поэтому сложно сказать о наличие какой-либо действительно существующей зависимости.
#
# ---
# [Вернуться к содержанию](#Содержание)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>  Решено верно, молодец!

# %% [markdown]
# ---
# <a class="anchor" id="7"></a>
# ### Задача 7
#
# Сгруппируйте данные по названиям заведений и найдите топ-15 популярных сетей в Москве. Для них посчитайте значения среднего рейтинга. Под популярностью понимается количество заведений этой сети в регионе. К какой категории заведений они относятся? Результат сопроводите подходящими визуализациями.

# %%
rest_top_15 = df.groupby(['name', 'category']).agg({'id':'count'}).sort_values(by='id', ascending=False).head(15)

# %%
rest_top_15_res_ind = rest_top_15.reset_index()
rest_top_15_res_ind.rename(columns={'id':'total'}, inplace=True)

# %%
rest_top_15_res_ind
# Out:
#                                    name         category  total
# 0                                  кафе             кафе    159
# 1                           шоколадница          кофейня    119
# 2                        домино'с пицца         пиццерия     77
# 3                            додо пицца         пиццерия     74
# 4                      one price coffee          кофейня     72
# 5                          яндекс лавка         ресторан     69
# 6                                 cofix          кофейня     65
# 7                                 prime         ресторан     49
# 8                              кофепорт          кофейня     42
# 9   кулинарная лавка братьев караваевых             кафе     39
# 10                              теремок         ресторан     36
# 11                             ресторан         ресторан     33
# 12                               шаурма  быстрое питание     32
# 13                             cofefest          кофейня     31
# ...

# %%
plt.figure(figsize=(10,6))

ax = sns.barplot(rest_top_15_res_ind, x='total', y='name', hue='category', palette='muted')

for i in range(5):
    ax.bar_label(ax.containers[i], fontsize=10, color='black', fmt='%d', padding=1)

plt.title("Топ-15 заведений по количеству точек в Москве")
plt.ylabel("Название заведения")
plt.xlabel("Количество")
plt.tight_layout()
plt.show()

# %%
df[df['name'] == 'кафе'].head()
# Out:
#                                    id  name category  \
# 40   e5f4ff8c7196472eac2c980fc6b2e9b2  кафе     кафе
# 47   de2745a7b3984016ad267fc062467e8b  кафе     кафе
# 108  a9ad4bd7e15c4b8cb6295c745e5a11c1  кафе  бар,паб
# 123  e14d752227704822964731977a47d198  кафе     кафе
# 141  03e4cbbd86de4014a22ccd8249c85a6d  кафе     кафе
#
#                                   address  \
# 40     москва, ижорская улица, 18, стр. 1
# 47     москва, улица маршала федоренко, 7
# 108     москва, мкад, 82-й километр, вл18
# 123         москва, шенкурский проезд, 14
# 141  москва, дубнинская улица, 52, стр. 1
#
#                                     district                   hours  rating  \
# 40           Северный административный округ              не указано     3.7
# 47           Северный административный округ  ежедневно, 11:00–00:00     2.8
# 108  Северо-Восточный административный округ              не указано     4.2
# ...

# %%
df[df['name'] == 'кафе']['category'].unique()
# Out:
# array(['кафе', 'бар,паб', 'кофейня', 'столовая', 'быстрое питание',
#        'ресторан', 'пиццерия'], dtype=object)

# %% [markdown]
# Вывод:
# - Наиболее популярными заведениями в Москве по количеству точек являются "Шоколадница", "Додо Пицца", "Доминос'с Пицца","One Price Coffee", "Яндекс Лавка", "Cofix" и "кафе";
# - Топ-3 заведений относятся к категориям пиццерий и кофеен;
# - В целом, наиболее популярными категориями в этом топе являются кафе, кофейни, пиццерии и рестораны.
#
# Также присутствуют данные, заставляющие насторожиться:
# - Заведение с название "Кафе" - поисковик сказал, что такого не существует, а то, что у заведений с таким названием присутствует 7 из 8 категорий ещё больше даёт понять, что в данных присутствует ошибка;
# - Наличи здесь Яндекс Лавки. Насколько мне позволил посмотреть поисковик, если говорить о физических точках, то среди таких у Яндекс Лавки есть только точки типа кафе, то есть в данном варианте к Яндекс Лавке могут относиться, например, онлайн доставки, что является ошибкой.
#
# ---
# [Вернуться к содержанию](#Содержание)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>  Также правильно, молодец!

# %% [markdown]
# ---
# <a class="anchor" id="8"></a>
# ### Задача 8
#
# Изучите вариацию среднего чека заведения (столбец `middle_avg_bill`) в зависимости от района Москвы. Проанализируйте цены в Центральном административном округе и других. Как удалённость от центра влияет на цены в заведениях? Результат сопроводите подходящими визуализациями.

# %% [markdown]
# - **Все административные районы по отдельности**

# %%
df_1 = df[df['middle_avg_bill'] != -1]

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3149 entries, 1 to 8403
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 3149 non-null   object
#  1   name               3149 non-null   object
#  2   category           3149 non-null   object
#  3   address            3149 non-null   object
#  4   district           3149 non-null   object
#  5   hours              3149 non-null   object
#  6   rating             3149 non-null   float64
#  7   chain              3149 non-null   bool
#  8   seats              3149 non-null   int32
#  9   price              3149 non-null   object
#  10  avg_bill           3149 non-null   object
#  11  middle_avg_bill    3149 non-null   float64
#  12  middle_coffee_cup  3149 non-null   float64
#  13  is_24_7            3149 non-null   bool
# dtypes: bool(2), float64(3), int32(1), object(8)
# memory usage: 313.7+ KB

# %%
districts_grouped = df_1.groupby('district').agg({'middle_avg_bill':'mean'}).sort_values(by='middle_avg_bill', ascending=False)
districts_grouped
# Out:
#                                          middle_avg_bill
# district
# Центральный административный округ           1191.057547
# Западный административный округ              1053.225490
# Северный административный округ               927.959627
# Южный административный округ                  834.398089
# Северо-Западный административный округ        822.222930
# Восточный административный округ              820.626923
# Юго-Западный административный округ           792.561702
# Северо-Восточный административный округ       716.611296
# Юго-Восточный административный округ          654.097938

# %%
plt.figure(figsize=(10,6))

ax = sns.barplot(districts_grouped.reset_index(), x='middle_avg_bill', y='district', hue='district', palette='inferno')

plt.xlim(0, districts_grouped['middle_avg_bill'].max() * 1.15)

for i in range(len(list(df['district'].unique()))):
    ax.bar_label(ax.containers[i], fontsize=10, color='black', fmt='%.2f', padding=3)

plt.title("Средний чек по регионам Москвы")
plt.ylabel("Район")
plt.xlabel("Средний чек")
plt.tight_layout()
plt.show()

# %% [markdown]
# Это, конечно, достаточно поверхностная оценка "удаленности" от центра, но видно, что в других округах средние чеки меньше, нежели в центре. Однако, следующие график и таблица более показательны.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>  Решено правильно, молодец!

# %% [markdown]
# Дополнительно построю корреляционную матрицу

# %%
columns = ['district', 'middle_avg_bill']

matrix_1 = df_1[columns].phik_matrix()
# Out:
# interval columns not set, guessing: ['middle_avg_bill']

# %%
plt.figure(figsize=(8,6))

sns.heatmap(matrix_1, annot=True, cmap='coolwarm')

plt.title("Корреляционная матрица phi_k")
plt.ylabel("")
plt.xlabel("")
plt.tight_layout()
plt.show()

# %% [markdown]
# Какая-либо корреляция почти полностью отсутствует, то есть с точки зрения корреляционного анализа связи нет.

# %% [markdown]
# - **Разделение на центральный район и остальные**

# %%
df_copy = df.copy()

# %%
df_copy['district'] = df_copy['district'].apply(lambda x: "Центральный административный округ" if x == "Центральный административный округ" else "Остальные округа")

df_2 = df_copy[df_copy['middle_avg_bill'] != -1]

cent_and_other_districts = df_2.groupby('district').agg({'middle_avg_bill':'mean'}).sort_values(by='middle_avg_bill', ascending=False)
cent_and_other_districts
# Out:
#                                     middle_avg_bill
# district
# Центральный административный округ      1191.057547
# Остальные округа                         839.822882

# %%
plt.figure(figsize=(10,6))

ax = sns.barplot(cent_and_other_districts.reset_index(), x='middle_avg_bill', y='district', hue='district', palette='inferno')

plt.xlim(400, cent_and_other_districts['middle_avg_bill'].max() * 1.15)

for i in range(2):
    ax.bar_label(ax.containers[i], fontsize=10, color='black', fmt='%.2f', padding=3)

plt.title("Средний чек по Центральному адм. округу Москвы и другим округам")
plt.ylabel("Район")
plt.xlabel("Средний чек")
plt.tight_layout()
plt.show()

# %% [markdown]
# На этом графике видно, что средний чек в центре больше, нежели в других, отдалённых, регионах. Однако, оценить отдалённость всё равно достаточно сложно.

# %%
columns = ['district', 'middle_avg_bill']

matrix_2 = df_2[columns].phik_matrix()
# Out:
# interval columns not set, guessing: ['middle_avg_bill']

# %%
plt.figure(figsize=(8,6))

sns.heatmap(matrix_2, annot=True, cmap='coolwarm')

plt.title("Корреляционная матрица phi_k")
plt.ylabel("")
plt.xlabel("")
plt.tight_layout()
plt.show()

# %% [markdown]
# Странно, но и здесь никакой связи между чеком и расположением нет.
#
# ---
# [Вернуться к содержанию](#Содержание)

# %% [markdown]
# ---
# <a class="anchor" id="9"></a>
# ### Задача 9
#
#  При необходимости проведите исследования других данных и их взаимосвязи. Например, часы работы заведений или стоимость чашки кофе в зависимости от расположения или типа заведения.

# %% [markdown]
# В дополнение к прошлой задаче проведу дополнительное исследование по зависимости стоимости чашки кофе от расположения.

# %%
df.columns
# Out:
# Index(['id', 'name', 'category', 'address', 'district', 'hours', 'rating',
#        'chain', 'seats', 'price', 'avg_bill', 'middle_avg_bill',
#        'middle_coffee_cup', 'is_24_7'],
#       dtype='object')

# %%
df_3 = df_copy[df_copy['middle_coffee_cup'] != -1]

cent_and_other_districts_for_coffee = df_3.groupby('district').agg({'middle_coffee_cup':'mean'}).sort_values(by='middle_coffee_cup', ascending=False)

# %%
plt.figure(figsize=(10,6))

ax = sns.barplot(cent_and_other_districts_for_coffee.reset_index(), x='middle_coffee_cup', y='district', hue='district', palette='inferno')

plt.xlim(100, cent_and_other_districts_for_coffee['middle_coffee_cup'].max() * 1.15)

for i in range(2):
    ax.bar_label(ax.containers[i], fontsize=10, color='black', fmt='%.2f', padding=3)

plt.title("Оценка стоимости чашки капучино по Центральному адм. округу Москвы и другим округам")
plt.ylabel("Район")
plt.xlabel("Стоимость чашки")
plt.tight_layout()
plt.show()

# %%
columns = ['district', 'middle_coffee_cup']

matrix_3 = df_3[columns].phik_matrix()
# Out:
# interval columns not set, guessing: ['middle_coffee_cup']

# %%
plt.figure(figsize=(8,6))

sns.heatmap(matrix_3, annot=True, cmap='coolwarm')

plt.title("Корреляционная матрица phi_k")
plt.ylabel("")
plt.xlabel("")
plt.tight_layout()
plt.show()

# %% [markdown]
# В этом случае связь между стоимостью одного капучино и округом есть, однако с точки зрения средних значений она намного менее явная. Тем не менее этот коэффициент корреляции все равно незначителен и конкретного подтверждения зависимости нет.
#
# ---
# [Вернуться к содержанию](#Содержание)

# %% [markdown]
# ---
# <a class="anchor" id="10"></a>
# ### Промежуточный вывод
#
# Обобщите полученные результаты, выделив, по вашему мнению, самые важные.

# %% [markdown]
# - Наиболее популярными заведениями в Москве по количеству точек с большим отрывом являются "Шоколадница", "Додо Пицца" и "Доминос'с Пицца";
#   - Топ-3 заведений относятся к категориям пиццерий и кофеен.
# - Корреляционной зависимости между округом и средним чеком или стоимостью одной чашки капучино нет, но графически опредленная зависимость между средним чеком и округом есть - однако, по этому делать вывод поспешно;
# - В целом, несетевых заведений больше, причем существенно - практически на 2000 заведений, и это при том, что всего заведений 8406;
#   - Наибольшая доля сетевых заведений в таких категориях, как булочные, кофейни и пиццерии;
#   - Наименьшая доля сетевых заведений в категориях: бар, паб, столовая и кафе.
# - Конкретных и высоких зависимостей в данных не обнаружено;
# - В данных присутствуют аномалии, которые следовало бы более подробно изучить при последующем анализе.
# ---
# [Вернуться к содержанию](#Содержание)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>  В точку!

# %% [markdown]
# <div class="alert alert-info">
# <b>Тут также подправил</b>
# </div>

# %% [markdown]
# <a class="anchor" id="Итоговый-вывод"></a>
# ## Итоговый вывод и рекомендации
#
# По результатам проведённого исследовательского анализа данных сформулируйте итоговый вывод и рекомендации для заказчика. Старайтесь акцентировать внимание на ключевых моментах исследования.
#
# При составлении вывода придерживайтесь такой структуры:
#
# 1. Общий обзор проделанной работы.
# 2. Ответы на исследовательские вопросы, или главные выводы.
# 3. Рекомендации на основе анализа данных.

# %% [markdown]
# ### Общий обзор проделанной работы

# %% [markdown]
# - Проведено знакомство с данными, выяснены ключевые шаги для дальнейших действий;
# - Объеденены 2 датасета;
# - Данные приведенены к соответствующим типам;
# - Заполнены пропуски, при этом отсутствует удаление каких-либо строк;
# - Явных дубликатов не было, для избежания неявных данные были приведены к соответствующему для избежания проблем виду;
# - Выполнен исследовательский анализ.

# %% [markdown]
# ### Ответы на исследовательские вопросы

# %% [markdown]
# "Какие категории заведений представлены в данных?"
#
# - В данных представлено 8 категорий:ресторан, кофейня, кафе, бар,паб, пиццерия, быстрое питание, столовая и булочная.
#
# "Какие административные районы Москвы присутствуют в данных?"
#
# - В данных присутствуют такие административные районы Москвы:
#   - Центральный административный округ;
#   - Северный административный округ;
#   - Южный административный округ;
#   - Северо-Восточный административный округ;
#   - Западный административный округ;
#   - Восточный административный округ;
#   - Юго-Западный административный округ;
#   - Юго-Восточный административный округ;
#   - Северо-Западный административный округ.
#
# "Каких заведений больше — сетевых или несетевых?"
#
# - В данных больше несетевых заведений больше, причем существенно - практически на 2000 заведений, и это при том, что всего заведений 8406;
#
# "Какие категории заведений чаще являются сетевыми?"
#
# - Наибольшая доля сетевых заведений в таких категориях, как булочные, кофейни и пиццерии;
# - Наименьшая доля сетевых заведений в категориях: бар, паб, столовая и кафе.
#
# "Встречаются ли в данных аномальные значения или выбросы?"
#
# - В данных встречается аномальное количество посадочных мест - и их нулевое количество в условных ресторанах, их и их огромное количество в ресторанах, булочных и томк подобное, но это только столбец, по которому было задание проанализировать. Также выбросы присутсвуют и в других столбцах.
#
# "Если да, то с чем они могут быть связаны?"
#
# - Есть несколько вариантов, с чем они могут быть связаны, но вот основные:
#   - Нулевые значения могут быть связаны с отсутствием посадочных мест в связи с моделью работы заведения (такое свойственно булочным или кофейням) или с ошибкой в данных;
#   - Большие значения могут быть связаны с наличием у заведений площад для организации достаточно существенных мероприятий или ж просто с ошибко в заполнении.
#
# "Сильно ли различаются усреднённые рейтинги для разных типов общепита?"
#
# - По данному рейтингу видно, что отличия рейтинг несущественны. В среднем рейтинг у каждой категории держится на уровне 4.10-4.20 с небольшими погрешностями в меньшую или большую стороны, что несущественно.
#
# "К какой категории заведений относятся топ-15 заведений Москвы?"
#
# - В целом, наиболее популярными категориями в этом топе являются кафе, кофейни, пиццерии и рестораны. Однако, также присутсвует и одно заведение быстрого питания.
#
# "Как удалённость от центра влияет на цены в заведениях?"
#
# - Если говорить о среднем чеке, то он уменьшает с удалением от цента, но корреляция не подтверждает наличие связи между ними.
# - Также уменьшается и оценочная стоимость одной чашки капучино при удалении от центра, но и здесь корреляция имеет незначительный уровень.

# %% [markdown]
# ### Рекомендации на основе анализа данных

# %% [markdown]
# - В первую очередь, продолжить исследование данных, ибо в них встречается достаточно много аномальных данных: выбросы, заведение "кафе", рестораны "Яндекс Лавки". Если продолжать анализ и проверять какие-либо гипотезы, то придется поработать и с распределением данных (либо же использовать бутстреп);
# - В любом случае, по моему субъективному мнению, тут требуется ещё большее количество исследований - возможно, даже по каким-то другим данным.
# ---
# - В зависимсоти от своего желания, инвесторы могут зайти в категорию заведений с высоким средним чеком и соответственно при правильной модели их работы высоким доходом, но с огромной конкуренцией, такие категгории, как рестораны, пиццерии или кофейни;
# - Или же они могут занять нишу с меньшим количеством конкурентнов, но с незначительно более низкими средними чеками и приблизительно с такими же другими показателями.
# ---
# - В заключении, по данному анализу сложно рассуждать о том, куда стоит вкладываться инвесторам, поэтому самой главной рекомендацией является продолжение данного анализа, особенно проверка гипотез, а также проведение дополнительных исследований, которые более глубоко затронут поднаготную бизнеса заведений общественного питания.
#
# ---
# [Вернуться к содержанию](#Содержание)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Итоговый вывод нужно доработать после исправления ошибок выше

# %% [markdown]
# <div class="alert alert-info">
# <b>Доработал. Если я правильно понял, то надо было исправить только про долю сетевых заведений в разрезе категорий</b>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v3 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Да, молодец!

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту ревьювера v1**:
#
# Егор, спасибо за  проект! Ты приложил много усилий, чтобы довести его до конца, проделана огромная работа, и это видно невооруженным глазом, ты большой молодец!
#
# **Отмечу положительные моменты**:
#
# 1. Все разложено по полочкам, всегда понятен ход твоих мыслей, приятно смотреть
#
# 2. Отличные визуализации
#
# 3. На разных шагах проекта ты предлагал очень интересные решения и методы для их реализации. Хорошая работа!
#
# **На что стоит обратить внимание**:
#
# 1. Не все задания выполнены верно
#
# **Удачи и жду твой проект на повторное ревью!**

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту ревьювера v1**:
#
# Егор, ошибка исправлена, проект принят, поздравляю тебя!
